# %%
#Important Libraries
import pandas as pd

# %%
scopus_data = pd.read_csv("./scopus_final.csv")
wos_data = pd.read_csv("./wos_final.csv")
sd_data = pd.read_csv("./sciencedirect_final.csv")

# %%
# Display column names in each dataset to identify discrepancies
print("Scopus columns:", scopus_data.columns)
print("Web of Science columns:", wos_data.columns)
print("ScienceDirect columns:", sd_data.columns)
# Out:
# Scopus columns: Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Tradenames', 'Manufacturers', 'Funding Details', 'Funding Texts',
#        'References', 'Correspondence Address', 'Editors', 'Publisher',
#        'Sponsors', 'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')
# Web of Science columns: Index(['Publication Type', 'Authors', 'Book Authors', 'Book Editors',
#        'Book Group Authors', 'Author Full Names', 'Book Author Full Names',
#        'Group Authors', 'Article Title', 'Source Title', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Author Keywords', 'Keywords Plus', 'Abstract',
#        'Addresses', 'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Publication Year', 'Volume', 'Issue', 'Part Number', 'Supplement',
#        'Special Issue', 'Meeting Abstract', 'Start Page', 'End Page',
#        'Article Number', 'DOI', 'DOI Link', 'Book DOI', 'Early Access Date',
#        'Number of Pages', 'WoS Categories', 'Web of Science Index',
#        'Research Areas', 'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'Web of Science Record'],
#       dtype='object')
# ScienceDirect columns: Index(['Unnamed: 0', 'type_of_reference', 'primary_title', 'authors',
#        'journal_name', 'volume', 'number', 'start_page', 'end_page', 'year',
#        'date', 'secondary_title', 'issn', 'doi', 'urls', 'keywords',
#        'abstract'],
#       dtype='object')

# %%
# Rename columns for consistency
scopus_data.rename(columns={
    'Title': 'Title',
    'Authors': 'Authors',
    'Year': 'Year',
    'Source title': 'Source',
    'DOI': 'DOI',
    'Abstract': 'Abstract',
    'Author Keywords': 'Keywords',
    'Document Type': 'Document_Type'
}, inplace=True)

wos_data.rename(columns={
    'Article Title': 'Title',
    'Authors': 'Authors',
    'Publication Year': 'Year', 
    'Source Title': 'Source',
    'DOI': 'DOI',
    'Abstract': 'Abstract',
    'Author Keywords': 'Keywords', 
    'Document Type': 'Document_Type'
}, inplace=True)

sd_data.rename(columns={
    'primary_title': 'Title',
    'authors': 'Authors',
    'year': 'Year',
    'journal_name': 'Source',
    'doi': 'DOI',
    'abstract': 'Abstract',
    'keywords': 'Keywords',
    'type_of_reference': 'Document_Type'
}, inplace=True)

# Define required columns and add missing ones
columns_to_keep = ['Title', 'Abstract', 'Keywords', 'Source', 'Year', 'Document_Type', 'Authors', 'DOI']

# %%
# Drop duplicate columns in Scopus, Web of Science, and ScienceDirect dataframes

# For Scopus - Drop the second occurrence of 'Source'
scopus_data = scopus_data.loc[:, ~scopus_data.columns.duplicated()]

# For Web of Science - Drop the second occurrence of 'Keywords' and 'Document_Type'
wos_data = wos_data.loc[:, ~wos_data.columns.duplicated()]

# ScienceDirect already looks clean, but this ensures no duplicates
sd_data = sd_data.loc[:, ~sd_data.columns.duplicated()]

# Confirm column alignment after cleaning
print("Scopus data columns:", scopus_data.columns)
print("Web of Science data columns:", wos_data.columns)
print("ScienceDirect data columns:", sd_data.columns)
# Out:
# Scopus data columns: Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Keywords', 'Index Keywords',
#        'Molecular Sequence Numbers', 'Chemicals/CAS', 'Tradenames',
#        'Manufacturers', 'Funding Details', 'Funding Texts', 'References',
#        'Correspondence Address', 'Editors', 'Publisher', 'Sponsors',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document_Type', 'Publication Stage', 'Open Access', 'EID'],
#       dtype='object')
# Web of Science data columns: Index(['Publication Type', 'Authors', 'Book Authors', 'Book Editors',
#        'Book Group Authors', 'Author Full Names', 'Book Author Full Names',
#        'Group Authors', 'Title', 'Source', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document_Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Keywords', 'Keywords Plus', 'Abstract', 'Addresses',
#        'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Year', 'Volume', 'Issue', 'Part Number', 'Supplement', 'Special Issue',
#        'Meeting Abstract', 'Start Page', 'End Page', 'Article Number', 'DOI',
#        'DOI Link', 'Book DOI', 'Early Access Date', 'Number of Pages',
#        'WoS Categories', 'Web of Science Index', 'Research Areas',
#        'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'Web of Science Record'],
#       dtype='object')
# ScienceDirect data columns: Index(['Unnamed: 0', 'Document_Type', 'Title', 'Authors', 'Source', 'volume',
#        'number', 'start_page', 'end_page', 'Year', 'date', 'secondary_title',
#        'issn', 'DOI', 'urls', 'Keywords', 'Abstract'],
#       dtype='object')

# %%
# Ensure each dataset has all required columns, filling missing columns with NaN
scopus_data = scopus_data.reindex(columns=columns_to_keep)
wos_data = wos_data.reindex(columns=columns_to_keep)
sd_data = sd_data.reindex(columns=columns_to_keep)

# %%
# Concatenate all datasets
combined_data = pd.concat([scopus_data, wos_data, sd_data], ignore_index=True)

# Display basic information about the combined dataset to verify
print("Total records in combined dataset:", combined_data.shape[0])
print("Columns in combined dataset:", combined_data.columns)
combined_data.head()
# Out:
# Total records in combined dataset: 3649
# Columns in combined dataset: Index(['Title', 'Abstract', 'Keywords', 'Source', 'Year', 'Document_Type',
#        'Authors', 'DOI'],
#       dtype='object')
#                                                Title  \
# 0  A vision-enabled fatigue-sensitive human digit...
# 1  Knowledge transfer in Digital Twins: The metho...
# 2  A Dualistic Perspective of Opportunity and Ris...
# 3  A Segmentation Framework based on Cognitive Sc...
# 4  Putting workers’ safety front and center: Empl...
#
#                                             Abstract  \
# 0  Within a Human-centric Human-Robot Collaborati...
# 1  In the realm of Digital Twins (DTs), industry ...
# 2  Head-mounted augmented reality (HMD AR) techno...
# 3  Industry 5.0 rethinks the role of human operat...
# 4  Introduction: The global occupational accident...
#
#                                             Keywords  \
# 0  Ergonomics; Fatigue assessment; Human digital ...
# 1  Basic Formal Ontology (BFO); Common Core Ontol...
# 2  Cognitive behavior and performance; Cognitive ...
# 3  Cognitive Sciences; Human-Centricity; Industry...
# 4  Employee-organization exchange; Management com...
#
#                                               Source  Year     Document_Type  \
# 0                   Journal of Manufacturing Systems  2024           Article
# 1  CIRP Journal of Manufacturing Science and Tech...  2024           Article
# 2  Journal of Construction Engineering and Manage...  2024           Article
# 3     ACM International Conference Proceeding Series  2024  Conference paper
# 4                         Journal of Safety Research  2024           Article
#
#                                              Authors  \
# 0                          Chand S.; Zheng H.; Lu Y.
# 1  D'Amico R.D.; Sarkar A.; Karray M.H.; Addepall...
# 2                             Liu J.; Yan X.; Gao W.
# 3                                 Varni G.; Volpe G.
# 4                     Kuang H.-X.; Pan W.; Sun L.-Y.
#
#                            DOI
# 0   10.1016/j.jmsy.2024.10.002
# 1  10.1016/j.cirpj.2024.06.007
# 2   10.1061/JCEMD4.COENG-14684
# 3      10.1145/3656650.3656717
# 4    10.1016/j.jsr.2024.08.007

# %%
# Drop duplicate entries based on DOI
deduped_data = combined_data.drop_duplicates(subset="DOI", keep="first")

# In case some articles don’t have a DOI, we can further deduplicate based on Title and Authors
deduped_data = deduped_data.drop_duplicates(subset=["Title", "Authors"], keep="first")

# Display the number of unique articles after deduplication
print("Total records after deduplication:", deduped_data.shape[0])
deduped_data.head()
# Out:
# Total records after deduplication: 2678
#                                                Title  \
# 0  A vision-enabled fatigue-sensitive human digit...
# 1  Knowledge transfer in Digital Twins: The metho...
# 2  A Dualistic Perspective of Opportunity and Ris...
# 3  A Segmentation Framework based on Cognitive Sc...
# 4  Putting workers’ safety front and center: Empl...
#
#                                             Abstract  \
# 0  Within a Human-centric Human-Robot Collaborati...
# 1  In the realm of Digital Twins (DTs), industry ...
# 2  Head-mounted augmented reality (HMD AR) techno...
# 3  Industry 5.0 rethinks the role of human operat...
# 4  Introduction: The global occupational accident...
#
#                                             Keywords  \
# 0  Ergonomics; Fatigue assessment; Human digital ...
# 1  Basic Formal Ontology (BFO); Common Core Ontol...
# 2  Cognitive behavior and performance; Cognitive ...
# 3  Cognitive Sciences; Human-Centricity; Industry...
# 4  Employee-organization exchange; Management com...
#
#                                               Source  Year     Document_Type  \
# 0                   Journal of Manufacturing Systems  2024           Article
# 1  CIRP Journal of Manufacturing Science and Tech...  2024           Article
# 2  Journal of Construction Engineering and Manage...  2024           Article
# 3     ACM International Conference Proceeding Series  2024  Conference paper
# 4                         Journal of Safety Research  2024           Article
#
#                                              Authors  \
# 0                          Chand S.; Zheng H.; Lu Y.
# 1  D'Amico R.D.; Sarkar A.; Karray M.H.; Addepall...
# 2                             Liu J.; Yan X.; Gao W.
# 3                                 Varni G.; Volpe G.
# 4                     Kuang H.-X.; Pan W.; Sun L.-Y.
#
#                            DOI
# 0   10.1016/j.jmsy.2024.10.002
# 1  10.1016/j.cirpj.2024.06.007
# 2   10.1061/JCEMD4.COENG-14684
# 3      10.1145/3656650.3656717
# 4    10.1016/j.jsr.2024.08.007

# %%
deduped_data.to_csv("./deduped.csv")

# %%
#screened_data.to_csv("screened_data.csv", index=False)

# %%
source_counts = {}
for i, element in enumerate(deduped_data[deduped_data["Source"].notnull()]["Source"]):

    element = element.strip().lower()
    if element not in source_counts:
        source_counts[element] = 1
    else:
        source_counts[element] += 1
    # split = element.split(";") if type(element) is str else print("FUCK FUCK", element)
    # print(split)
    # for sc in element:
    # sc = sc.strip().lower()
    # if sc not in source_counts:
    # source_counts[sc] = 1
    # else:
    # source_counts[sc] += 1

# Convert the dictionary to a DataFrame
keywords_df = pd.DataFrame(list(source_counts.items()), columns=["sources", "count"])

# Sort the DataFrame by count in descending order (optional)
keywords_df = keywords_df.sort_values(by="count", ascending=False).reset_index(drop=True)

keywords_df.head(10)
# Out:
#                                           sources  count
# 0                                   procedia cirp    108
# 1                               ifac-papersonline     65
# 2  acm international conference proceeding series     55
# 3                       procedia computer science     55
# 4                          procedia manufacturing     50
# 5  robotics and computer-integrated manufacturing     49
# 6                              applied ergonomics     49
# 7                                  safety science     48
# 8  international journal of industrial ergonomics     36
# 9                advanced engineering informatics     31

# %%
# Group by Document_Type and Source, then count occurrences
source_counts = deduped_data.groupby(["Document_Type", "Source"]).size().reset_index(name="count")

# Sort the counts for better readability (optional)
source_counts = source_counts.sort_values(by="count", ascending=False).reset_index(drop=True)

# Separate the counts for journals and conferences (optional)
journal_counts = source_counts[source_counts["Document_Type"] == "Journal"]
conference_counts = source_counts[source_counts["Document_Type"] == "Conference"]

# Display the top 10 for each type (optional)
print("Top 10 Journals:")
print(journal_counts.head(20))

print("\nTop 10 Conferences:")
print(conference_counts.head(20))
# Out:
# Top 10 Journals:
#    Document_Type                                             Source  count
# 0        Journal                                      Procedia CIRP     59
# 3        Journal                                     Safety Science     47
# 4        Journal                                 Applied Ergonomics     47
# 5        Journal     Robotics and Computer-Integrated Manufacturing     47
# 6        Journal                                  IFAC-PapersOnLine     35
# 7        Journal                   Advanced Engineering Informatics     31
# 9        Journal                   Journal of Manufacturing Systems     30
# 11       Journal                          Procedia Computer Science     27
# 12       Journal                             Procedia Manufacturing     26
# 13       Journal                     Applied Sciences (Switzerland)     26
# 14       Journal                       Sustainability (Switzerland)     26
# 16       Journal     International Journal of Industrial Ergonomics     23
# 17       Journal                                        IEEE Access     21
# 18       Journal                            Frontiers in Psychology     20
# 19       Journal                 Computers & Industrial Engineering     19
# 21       Journal               Computers and Industrial Engineering     18
# 22       Journal                                            Sensors     17
# 23       Journal        Technological Forecasting and Social Change     17
# 24       Journal  International Journal of Occupational Safety a...     16
# 25       Journal  Journal of Construction Engineering and Manage...     16
#
# Top 10 Conferences:
#    Document_Type                                             Source  count
# 1     Conference     ACM International Conference Proceeding Series     55
# 2     Conference                                      Procedia CIRP     49
# 8     Conference                                  IFAC-PapersOnLine     30
# 10    Conference                          Procedia Computer Science     28
# 15    Conference                             Procedia Manufacturing     24
# 20    Conference  Conference on Human Factors in Computing Syste...     18
# 26    Conference  Proceedings of SPIE - The International Societ...     15
# 32    Conference  Proceedings - IEEE International Conference on...     13
# 34    Conference  IEEE International Conference on Automation Sc...     12
# 35    Conference  ACM/IEEE International Conference on Human-Rob...     12
# 38    Conference          Advances in Transdisciplinary Engineering     11
# 43    Conference  IEEE International Conference on Intelligent R...     10
# 48    Conference  Proceedings of the ASME Design Engineering Tec...      8
# 50    Conference  2014 36th Annual International Conference of t...      7
# 53    Conference  IEEE International Conference on Industrial En...      7
# 55    Conference  IOP Conference Series: Materials Science and E...      7
# 58    Conference  IEEE International Symposium on Industrial Ele...      6
# 59    Conference  Proceedings of the Annual International Confer...      6
# 61    Conference  Proceedings of the Annual Offshore Technology ...      6
# 65    Conference  Proceedings of the 32nd European Safety and Re...      6

# %%
# Check distribution by year
print(deduped_data["Year"].value_counts().sort_index())

# # Check top journals
# print(deduped_data["journal"].value_counts().head(20))

# # Check top conferences
# print(deduped_data["conferences"].value_counts().head(20))

# Analyze frequent keywords
keywords = deduped_data["Keywords"].str.split(",").explode().value_counts().head(20)
print(keywords)
# Out:
# Year
# 2014     98
# 2015    124
# 2016    137
# 2017    170
# 2018    179
# 2019    277
# 2020    281
# 2021    288
# 2022    379
# 2023    354
# 2024    390
# 2025      1
# Name: count, dtype: int64
# Keywords
#  'Industry 4.0'               20
# ['Industry 4.0'               14
#  'Industry 5.0'               10
#  'Ergonomics'                 10
# ['Augmented reality'          10
#  'Human factors'               9
#  'Virtual reality'             9
#  'Manufacturing'               8
#  'Artificial intelligence'     7
# ['Artificial intelligence'     7
#  'Assembly'                    7
#  'Eye-tracking'                6
#  'Cognitive ergonomics'        6
#  'Industry 4.0']               6
#  'Operator 4.0'                5
#  'Human error'                 5
#  'Mental workload'             5
#  'Smart manufacturing'         5
#  'Industry 5.0']               5
#  'Cognitive workload'          5
# Name: count, dtype: int64

# %%
# Get unique journal names
unique_journals = deduped_data[deduped_data["Document_Type"] == "Journal"]["Source"].unique()

# Get unique conference names
unique_conferences = deduped_data[deduped_data["Document_Type"] == "Conference"]["Source"].unique()

# Display the results
print("Unique Journals:")
print(unique_journals)

print("\nUnique Conferences:")
print(unique_conferences)
# Out:
# Unique Journals:
# ['Journal of Manufacturing Systems'
#  'CIRP Journal of Manufacturing Science and Technology'
#  'Journal of Construction Engineering and Management'
#  'Journal of Safety Research'
#  'Journal of Civil Engineering and Management' 'Batteries'
#  'Virtual Reality' 'Pattern Analysis and Applications'
#  'Cognitive Computation' 'ACM Transactions on Human-Robot Interaction'
#  'Manufacturing Letters' 'Behaviour Research and Therapy'
#  'Technological Forecasting and Social Change'
#  'Robotics and Computer-Integrated Manufacturing'
#  'International Journal of Advanced Manufacturing Technology'
#  'Soft Computing' 'Machines' 'Building and Environment' 'Buildings'
#  'Management and Production Engineering Review' 'Applied Psychology'
#  'Advanced Engineering Informatics' 'Safety Science'
#  'Computers in Industry' 'BMC Psychology' 'Interacting with Computers'
#  'Computer Applications in Engineering Education'
#  'Sustainability (Switzerland) ' 'Personal and Ubiquitous Computing'
#  'Mining, Metallurgy and Exploration'
#  'Journal of Applied Research in Intellectual Disabilities'
#  'Artificial Intelligence for Engineering Design, Analysis and Manufacturing: AIEDAM'
#  'Journal of Health and Safety at Work' 'Automation in Construction'
#  'Current Psychology' 'International Journal of Intercultural Relations'
#  'Human Factors and Ergonomics in Manufacturing and Service Industries'
#  'Computers and Security' 'Sustainability (Switzerland)'
#  'Organizational Psychology Review' 'Ocean Engineering'
#  "Journal of Alzheimer's Disease" 'Journal of Applied Behavioral Science '
#  'Expert Systems with Applications' 'BioData Mining'
#  'Information (Switzerland)' 'Kybernetes' 'Personnel Review'
#  'European Journal of Operational Research'
#  'Sustainable Production and Consumption' 'Advanced Healthcare Materials'
#  'Computers and Industrial Engineering' 'Applied Ergonomics'
#  'Computers in Human Behavior' 'Production and Operations Management'
#  'Innovations in Systems and Software Engineering'
#  'Applied Sciences (Switzerland)' 'ACS Nano'
#  'International Journal of Reconfigurable and Embedded Systems'
#  'Rock Mechanics and Rock Engineering' 'Appetite'
#  'Central European Management Journal' 'Human Factors'
#  'Nuclear Engineering and Design'
#  'Journal of Loss Prevention in the Process Industries'
#  'Journal of Neural Engineering' 'Frontiers in Human Neuroscience'
#  'Sensors' 'Cognitive Science'
#  'IEEE Transactions on Industrial Electronics'
#  'IEEE Transactions on Visualization and Computer Graphics'
#  'Journal of Cleaner Production' 'Production Engineering'
#  'Multimedia Tools and Applications'
#  'International Journal of Control, Automation and Systems'
#  'Neuropsychopharmacology Reports'
#  'International Journal of Humanoid Robotics' 'Stress and Health'
#  'ACM Transactions on Cyber-Physical Systems'
#  'Journal of Management in Engineering'
#  'Brazilian Journal of Operations and Production Management'
#  'IEEE Transactions on Human-Machine Systems'
#  'Advanced Intelligent Systems'
#  'IEEE Transactions on Intelligent Vehicles'
#  'IEEE Transactions on Consumer Electronics'
#  'International Journal of Social Robotics'
#  'Journal of Intelligent Manufacturing' 'Journal of Workplace Learning'
#  'Computers and Chemical Engineering'
#  'ACM Transactions on Accessible Computing'
#  'IEEE Internet of Things Magazine' 'Environmental Modelling and Software'
#  'Displays' 'Mathematics' 'Human Factors and Ergonomics In Manufacturing'
#  'Information and Software Technology' 'Frontiers in Robotics and AI'
#  'IEEE Access' 'Interactive Learning Environments'
#  'IEEE Transactions on Cognitive and Developmental Systems'
#  'EAI Endorsed Transactions on Internet of Things'
#  'Sensors (Basel, Switzerland)'
#  'IEEE Transactions on Automation Science and Engineering'
#  'International Journal of Advanced Computer Science and Applications'
#  'CIRP Annals' 'Annual Reviews in Control' 'Frontiers in Psychology'
#  'Journal of Applied Psychology'
#  'IEEE Transactions on Engineering Management' 'Wearable Technologies'
#  'International Journal of Computer Integrated Manufacturing'
#  'Journal of Engineering Education Transformations' 'PsyCh Journal'
#  'Iraqi Journal for Electrical and Electronic Engineering'
#  'Journal of Engineering Design'
#  'International Journal of Production Economics'
#  'International Journal of Occupational Safety and Ergonomics'
#  'Journal of Space Safety Engineering'
#  'International Journal of Human-Computer Interaction'
#  'Neuropsychological Trends' 'Discover Artificial Intelligence'
#  'IEEE Communications Surveys and Tutorials' 'PeerJ Computer Science'
#  'Cognitive Computation and Systems'
#  'Engineering Applications of Artificial Intelligence' 'IISE Transactions'
#  'Acta Polytechnica Hungarica'
#  'International Journal of Integrated Engineering' 'Computers'
#  'Journal of Industrial Information Integration'
#  'SAE International Journal of Advances and Current Practices in Mobility'
#  'Granular Computing' 'Software and Systems Modeling'
#  'Internet of Things (Netherlands)'
#  'Green Technologies and Sustainability'
#  'Multimodal Technologies and Interaction'
#  'Journal of Engineering Education' 'Smart Cities' 'Robotics'
#  'Journal of Mechanical Design'
#  'International Arab Journal of Information Technology'
#  'Transactions on Maritime Science' 'Applied System Innovation'
#  'IEEE Transactions on Cybernetics' 'IEEE Transactions on Smart Grid'
#  'Systems Engineering' 'International Journal of Reliability and Safety'
#  'IEEE Transactions on Industrial Informatics'
#  'Accident Analysis and Prevention' 'Biomedizinische Technik'
#  'IEEE Transactions on Intelligent Transportation Systems'
#  'Transportation Research Interdisciplinary Perspectives'
#  'Nature Human Behaviour'
#  'Engineering, Construction and Architectural Management'
#  'Artificial Intelligence Review'
#  'Journal of Occupational and Organizational Psychology'
#  'Journal of Ambient Intelligence and Humanized Computing'
#  'Journal of King Saud University - Computer and Information Sciences'
#  'IEEE Transactions on Industry Applications' 'Computer Communications'
#  'Industrial Robot' 'Adaptive Behavior' 'Friction'
#  'International Journal of Architectural Computing' 'Technovation'
#  'Neurocomputing' 'Big Data and Cognitive Computing'
#  'Journal of Cognitive Engineering and Decision Making'
#  'Journal of Integrated Design and Process Science'
#  'Electronics (Switzerland)'
#  'Journal of Information Technology in Construction'
#  'Journal of Intelligence'
#  'Iranian Journal of Science and Technology - Transactions of Civil Engineering'
#  'EAI Endorsed Transactions on Energy Web'
#  'Frontiers in Artificial Intelligence'
#  'IEEE Transactions on Systems, Man, and Cybernetics: Systems'
#  'Cognition, Technology and Work' 'Education Sciences'
#  'Future Generation Computer Systems' 'Computers, Materials and Continua'
#  'International Journal of Selection and Assessment'
#  'Architectural Engineering and Design Management'
#  'Computers and Electrical Engineering' 'Health Psychology Report'
#  'International Journal of Production Research'
#  'Transportation Research Part F: Traffic Psychology and Behaviour'
#  'Risk Analysis' 'Neural Computing and Applications'
#  'IEEE Pervasive Computing' 'Ergonomics in Design'
#  'Human-centric Computing and Information Sciences'
#  'Psychological Medicine'
#  'Disability and Rehabilitation: Assistive Technology'
#  'Robotics and Autonomous Systems' 'Construction Management and Economics'
#  'IEEE Transactions on Neural Systems and Rehabilitation Engineering'
#  'Psicologia em Estudo' 'IEEE Wireless Communications'
#  'Computers and Education: Artificial Intelligence'
#  'Interdisciplinary Journal of Information, Knowledge, and Management'
#  'International Journal of Consumer Studies' 'Energy'
#  'SN Applied Sciences' 'Pervasive and Mobile Computing'
#  'Frontiers in Neurorobotics' 'Alzheimer Disease and Associated Disorders'
#  'Human-Computer Interaction' 'Dyna (Spain)'
#  'Applied Clinical Informatics'
#  'Journal of Intelligent and Robotic Systems: Theory and Applications'
#  'Pacific Asia Journal of the Association for Information Systems'
#  'Safety' 'Perception'
#  'International Journal of Pavement Research and Technology'
#  'Journal of Interconnection Networks'
#  'IEEE Robotics and Automation Letters'
#  'Applied Mathematics and Nonlinear Sciences'
#  'Journal of Manufacturing Technology Management' 'OPSEARCH'
#  'Journal of the Society for Information Display' 'Design Issues'
#  'Information Systems and e-Business Management'
#  'International Journal of Molecular Sciences'
#  'Journal of Contemporary Psychotherapy' 'IEEE Internet of Things Journal'
#  'Symmetry' 'Digital Chemical Engineering'
#  'Journal of Marine Science and Engineering' 'Cognitive Systems Research'
#  'Comprehensive Psychiatry'
#  'International Journal on Interactive Design and Manufacturing'
#  'British Journal of Psychology'
#  'Journal of Computing in Civil Engineering'
#  'Journal of Reliable Intelligent Environments' 'AI and Society'
#  'Marketing, Zeitschrift fur Forschung und Praxis' 'Gerontechnology'
#  'IEEE Transactions on Biomedical Circuits and Systems'
#  'International Journal of Simulation and Process Modelling'
#  'Cyberpsychology, Behavior, and Social Networking'
#  'Cardiovascular Digital Health Journal'
#  'International Journal of Human Computer Studies'
#  'Behavior Research Methods' 'International Journal of Technology'
#  'Computers and Electronics in Agriculture'
#  'International Journal of Communication Networks and Information Security'
#  'Aerospace' 'Informatics in Education'
#  'Computational Intelligence and Neuroscience' 'Process Safety Progress'
#  'Computer-Aided Design and Applications'
#  'Applied Bionics and Biomechanics'
#  'AIDS Care - Psychological and Socio-Medical Aspects of AIDS/HIV'
#  'Psychology Research and Behavior Management' 'Complexity'
#  'Social Network Analysis and Mining'
#  'Advances in Production Engineering And Management'
#  'International Journal of Safety and Security Engineering'
#  'International Journal of Knowledge Management' 'Scientific Programming'
#  'Advances in Civil Engineering' 'Intelligent Decision Technologies'
#  'Neuropsychological Rehabilitation'
#  'IEEE Intelligent Transportation Systems Magazine'
#  'Evolutionary Intelligence' 'Thinking and Reasoning'
#  'Safety and Health at Work' 'BMC Medical Informatics and Decision Making'
#  'Applied Ontology' 'JMIR Serious Games'
#  'Intelligent Automation and Soft Computing'
#  'Journal of Machine and Computing' 'Software - Practice and Experience'
#  'Energies' 'Journal of Intelligent Information Systems'
#  'Philosophical Transactions of the Royal Society A: Mathematical, Physical and Engineering Sciences'
#  'Attention, Perception, and Psychophysics'
#  'International Journal of Robotics Research' 'Knowledge-Based Systems'
#  'Applied Soft Computing' 'IEEE Pulse'
#  'IEEE Communications Standards Magazine'
#  'Ethics and Information Technology'
#  'Reliability Engineering and System Safety' 'Human Resource Management'
#  'International Journal of Information Management'
#  'Complex and Intelligent Systems'
#  'Process Safety and Environmental Protection' 'Anales de Psicologia'
#  'International Journal of Machine Learning and Cybernetics'
#  'Transportation Engineering' 'Designs' 'Games and Culture'
#  'IEEE/ASME Transactions on Mechatronics'
#  'IEEE Transactions on Learning Technologies'
#  'IEEE Robotics and Automation Magazine'
#  'Information Technology and People' 'Scientific Visualization'
#  'IEEE Transactions on Instrumentation and Measurement'
#  'International Journal of Computers, Communications and Control'
#  'Journal of Marine Science and Application'
#  'International Journal of Communication Systems' 'Cognitive Robotics'
#  'IET Collaborative Intelligent Manufacturing'
#  'Sustainable Cities and Society' 'South African Journal of Psychology'
#  'FME Transactions' 'Journal of Enterprise Information Management'
#  'Microprocessors and Microsystems'
#  'Journal of Southeast University (English Edition)'
#  'Journal of Quality Technology'
#  'South African Journal of Industrial Engineering'
#  'Journal of Neuroscience, Psychology, and Economics'
#  'Applied Soft Computing Journal' 'Sensors (Switzerland)'
#  'Information Sciences' 'Robotica'
#  'Social and Personality Psychology Compass'
#  'Journal of Occupational Health Psychology'
#  'Production Planning and Control' 'PSU Research Review'
#  'Palgrave Communications' 'IEICE Transactions on Information and Systems'
#  'Journal of Experimental Psychology: General'
#  'Wireless Personal Communications'
#  'International Journal of Knowledge and  Systems Science'
#  'Engineering Reports' 'International Journal of Community Well-Being'
#  'IEEE Transactions on Neural Networks and Learning Systems'
#  'Australasian Journal of Information Systems'
#  'Journal of the Royal Society Interface'
#  'Indian Journal of Computer Science and Engineering'
#  'ASCE-ASME Journal of Risk and Uncertainty in Engineering Systems, Part B: Mechanical Engineering'
#  'Biomedical Engineering - Applications, Basis and Communications'
#  'Journal of Affective Disorders'
#  'Industrial and Engineering Chemistry Research' 'Body Image'
#  'Nature Machine Intelligence'
#  'Journal for the Theory of Social Behaviour'
#  'Australian Journal of Psychology' 'Neuropsychologia'
#  'Cybernetics and Systems' 'Ethics and Behavior' 'Journal of Road Safety'
#  'Psychology and Neuroscience' 'Archives of Clinical Neuropsychology'
#  'Applied Cognitive Psychology' 'Biomedical Signal Processing and Control'
#  'Elektrotechnik und Informationstechnik' 'Cogent Engineering'
#  'Journal of Intelligent and Fuzzy Systems'
#  'Journal of Mechanics in Medicine and Biology'
#  'IEEE Journal of Translational Engineering in Health and Medicine'
#  'Artificial Intelligence' 'Psychology and Aging'
#  'International Journal of Circuits, Systems and Signal Processing'
#  'Journal of the Association for Information Systems'
#  'Mathematical Problems in Engineering'
#  'International Journal of Serious Games'
#  'Journal of Youth and Adolescence' 'IEEE Transactions on Robotics'
#  'Biocybernetics and Biomedical Engineering' 'Entropy'
#  'Advances in Manufacturing'
#  'Journal of Computational Design and Engineering'
#  'Information and Computer Security' 'IEEE Communications Magazine'
#  'IEEE Transactions on Cognitive Communications and Networking'
#  'Journal of gambling studies'
#  'International Journal of Recent Technology and Engineering'
#  'Empirical Software Engineering'
#  'International Journal of Innovative Technology and Exploring Engineering'
#  'Journal of Experimental Child Psychology' 'Psychologist-Manager Journal'
#  'Autonomous Robots' 'Paladyn' 'Pollack Periodica' 'Human Technology'
#  'Journal of Economic Psychology' 'Production and Manufacturing Research'
#  'International Journal of Aerospace Engineering'
#  'Nature Biomedical Engineering'
#  'Smart and Sustainable Manufacturing Systems' 'Computer Graphics Forum'
#  'Journal of Management Information Systems'
#  'ECTI Transactions on Computer and Information Technology'
#  'Periodicals of Engineering and Natural Sciences'
#  'Journal of Computational and Theoretical Nanoscience'
#  'Computers and Graphics (Pergamon)' 'Spanish Journal of Psychology'
#  'IEEE Transactions on Transportation Electrification'
#  'International Journal of Computational Intelligence Systems'
#  'KI - Kunstliche Intelligenz'
#  'International Journal of Quality Engineering and Technology'
#  'International Journal of Mechanical and Production Engineering Research and Development'
#  'Journal of Vocational Behavior'
#  'IEEE Transactions on Vehicular Technology'
#  'ACM Transactions on Interactive Intelligent Systems' 'Sleep Health'
#  'Behaviour and Information Technology'
#  'International Journal of Advanced Robotic Systems'
#  'Journal of Operations Management'
#  'International Journal of System Assurance Engineering and Management'
#  'IT Professional' 'Journal of Computer Information Systems'
#  'Clinical Neuropsychologist'
#  'Building Services Engineering Research and Technology'
#  'American Psychologist' 'Psychophysiology'
#  'Communications of the Association for Information Systems'
#  'Mechatronics' 'Journal of Applied Social Psychology'
#  'KSCE Journal of Civil Engineering'
#  'AIMS Electronics and Electrical Engineering'
#  'Career Development Quarterly' 'Logistics Journal'
#  'Journal of Manufacturing Science and Engineering, Transactions of the ASME'
#  'Physiology and Behavior' 'Nanotechnologies in Russia'
#  'Frontiers in Neuroinformatics' 'AI Communications'
#  'APSIPA Transactions on Signal and Information Processing'
#  'Proceedings of the Institution of Mechanical Engineers, Part F: Journal of Rail and Rapid Transit'
#  'Proceedings of the Institution of Mechanical Engineers, Part O: Journal of Risk and Reliability'
#  'SA Journal of Industrial Psychology'
#  'Personality and Individual Differences'
#  'International Journal of Automation Technology'
#  'Journal of Failure Analysis and Prevention'
#  'Artificial Life and Robotics' 'Psicothema' 'Advanced Science Letters'
#  'Scientometrics' 'Journal of Network and Computer Applications'
#  'Digital Policy, Regulation and Governance '
#  'Perspectives on Psychological Science' 'Design Science'
#  'Chinese Journal of Aeronautics'
#  'Research in Psychotherapy: Psychopathology, Process and Outcome'
#  'Journal of Emerging Technologies in Accounting'
#  'CIRP Annals - Manufacturing Technology'
#  'Advances in Science, Technology and Engineering Systems'
#  'International Journal of Psychophysiology'
#  'Critical Reviews in Food Science and Nutrition'
#  'Wireless Communications and Mobile Computing' 'Proceedings of the IEEE'
#  'Journal of Engineering, Design and Technology' 'AI Magazine'
#  'Scientific and Technical Information Processing'
#  'Computer Methods and Programs in Biomedicine'
#  'Psychoanalytic Psychotherapy' 'IEEE Software'
#  'IEEE Transactions on Knowledge and Data Engineering'
#  'Cognitive Research: Principles and Implications'
#  'International Journal of Simulation: Systems, Science and Technology'
#  'International Journal of Sport Psychology' 'Cortex'
#  'Journal of Applied Security Research' 'Behavioural Neurology'
#  'IEEE Systems Journal' 'IRBM' 'Water Research'
#  'International Journal of Engineering, Transactions B: Applications'
#  'Journal of Experimental Psychology: Applied'
#  'Journal of Managerial Psychology' 'Computers in Biology and Medicine'
#  'Journal of Pediatric Psychology'
#  'Journal of Sensor and Actuator Networks'
#  'Journal of Software: Evolution and Process'
#  'Policy Insights from the Behavioral and Brain Sciences'
#  'Ethical Human Psychology and Psychiatry'
#  'Computer Supported Cooperative Work: CSCW: An International Journal'
#  'Human Resource Management Review'
#  'Journal of Materials Processing Technology' 'Simulation and Gaming'
#  'Journal on Multimodal User Interfaces'
#  'International Journal of Technology and Human Interaction'
#  'Journal of Strategic Information Systems' 'Telematics and Informatics'
#  'IET Microwaves, Antennas and Propagation' 'Jurnal Teknologi'
#  'Quality and Reliability Engineering International'
#  'Journal of Risk Research' 'VINE' 'Annals of Biomedical Engineering'
#  'Canadian Journal of Civil Engineering'
#  'Wiley Interdisciplinary Reviews: Cognitive Science'
#  'Journal of Industrial Engineering International' 'Cell Transplantation'
#  'IEEE Computational Intelligence Magazine'
#  'Journal of Information Security and Applications'
#  'Proceedings of Institution of Civil Engineers: Management, Procurement and Law'
#  'Journal of Psychotherapy Integration'
#  'Praxis der Kinderpsychologie und Kinderpsychiatrie'
#  'International Journal of Psychology'
#  'International Journal of Software Engineering and its Applications'
#  'JOURNAL OF INTELLIGENT MANUFACTURING' 'JOURNAL OF ENGINEERING DESIGN'
#  'SADHANA-ACADEMY PROCEEDINGS IN ENGINEERING SCIENCES'
#  'FRONTIERS IN VIRTUAL REALITY'
#  'INTERNATIONAL JOURNAL OF INDUSTRIAL ERGONOMICS' 'IEEE ACCESS'
#  'INTERNATIONAL JOURNAL OF PRODUCTION RESEARCH'
#  'INTERNATIONAL JOURNAL OF HUMAN-COMPUTER INTERACTION'
#  'PRODUCTION AND MANUFACTURING RESEARCH-AN OPEN ACCESS JOURNAL'
#  'PRODUCTION ENGINEERING-RESEARCH AND DEVELOPMENT'
#  'COGNITION TECHNOLOGY & WORK'
#  'JOURNAL OF MANUFACTURING TECHNOLOGY MANAGEMENT' 'SAFETY SCIENCE'
#  'ERGONOMICS'
#  'HUMAN FACTORS AND ERGONOMICS IN MANUFACTURING & SERVICE INDUSTRIES'
#  'TRANSLATION QUALITY ASSESSMENT: FROM PRINCIPLES TO PRACTICE'
#  'KSCE JOURNAL OF CIVIL ENGINEERING' 'APPLIED ERGONOMICS'
#  'ASSEMBLY AUTOMATION' 'TEHNICKI GLASNIK-TECHNICAL JOURNAL'
#  'JOURNAL OF INTEGRATED DESIGN & PROCESS SCIENCE'
#  'ROBOTICS AND COMPUTER-INTEGRATED MANUFACTURING' 'PROCESSES'
#  'FME TRANSACTIONS' 'PROCESS SAFETY AND ENVIRONMENTAL PROTECTION'
#  'INTERNATIONAL JOURNAL OF HUMAN-COMPUTER STUDIES'
#  'INTERNATIONAL JOURNAL OF COMPUTERS COMMUNICATIONS & CONTROL'
#  'BEHAVIOUR & INFORMATION TECHNOLOGY' 'TOPICS IN COGNITIVE SCIENCE'
#  'JOURNAL OF MANAGEMENT IN ENGINEERING' 'HUMAN FACTORS'
#  'JOURNAL OF THE AMERICAN MEDICAL INFORMATICS ASSOCIATION'
#  'COMPUTERS & EDUCATION' 'INDUSTRIAL ENGINEERING AND MANAGEMENT SYSTEMS'
#  'COMPUTERS & INDUSTRIAL ENGINEERING' 'AI MAGAZINE'
#  'TSINGHUA SCIENCE AND TECHNOLOGY'
#  'ENGINEER-JOURNAL OF THE INSTITUTION OF ENGINEERS SRI LANKA'
#  'APPLIED SCIENCES-BASEL' 'EXPERT SYSTEMS WITH APPLICATIONS'
#  'INTERNATIONAL JOURNAL OF TECHNOLOGY AND DESIGN EDUCATION'
#  'COGNITIVE DEVELOPMENT' 'JOURNAL OF MECHANICAL DESIGN'
#  'AUTOMATION IN CONSTRUCTION'
#  'KNOWLEDGE-BASED INFORMATION SYSTEMS IN PRACTICE'
#  'INTERNATIONAL JOURNAL OF LEAN SIX SIGMA'
#  'EUROPEAN JOURNAL OF INFORMATION SYSTEMS'
#  'JOURNAL OF SYSTEMS AND SOFTWARE' 'RISK AND COGNITION'
#  'ISPRS INTERNATIONAL JOURNAL OF GEO-INFORMATION'
#  'INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND NETWORK SECURITY'
#  'IEEE TRANSACTIONS ON COMPUTATIONAL SOCIAL SYSTEMS'
#  'HUMAN RESOURCE MANAGEMENT' 'PSYCHOLOGY OF LEADERS AND LEADERSHIP'
#  'NEW TRENDS IN MEDICAL AND SERVICE ROBOT: THEORY AND INTEGRATED APPLICATIONS'
#  'INTERNATIONAL JOURNAL OF COMPUTER INTEGRATED MANUFACTURING'
#  'SCIENTOMETRICS'
#  'INTERNATIONAL JOURNAL OF CRITICAL INFRASTRUCTURE PROTECTION'
#  'INGENIERIA E INVESTIGACION' 'INTERNATIONAL JOURNAL OF SPORT PSYCHOLOGY'
#  'IEEE-ACM TRANSACTIONS ON COMPUTATIONAL BIOLOGY AND BIOINFORMATICS'
#  'FRONTIERS OF ENGINEERING MANAGEMENT' 'JOURNAL OF ECOLOGICAL ENGINEERING'
#  'JOURNAL OF PERSONALITY AND SOCIAL PSYCHOLOGY'
#  'PSYCHOLOGY RESEARCH AND BEHAVIOR MANAGEMENT' 'INFORMATION FUSION'
#  'MACHINE INTELLIGENCE RESEARCH' 'HUMAN RESOURCE DEVELOPMENT QUARTERLY'
#  'DATA SCIENCE AND VISUAL COMPUTING' 'FIRE SAFETY JOURNAL'
#  'RECENT DEVELOPMENTS IN NEUROSCIENCE RESEARCH ON HUMAN MOTIVATION'
#  'STUDIES IN PSYCHOLOGY-PSIKOLOJI CALISMALARI DERGISI'
#  'JOURNAL OF HAZARDOUS MATERIALS ADVANCES'
#  'FRONTIERS IN HUMAN NEUROSCIENCE' 'FRONTIERS IN PSYCHOLOGY'
#  'IFAC-PapersOnLine' 'Procedia CIRP'
#  'International Journal of Industrial Ergonomics' 'Procedia Manufacturing'
#  'Computers & Industrial Engineering' 'Procedia Computer Science'
#  'Computers & Chemical Engineering' 'Computers & Graphics'
#  'International Journal of Mining Science and Technology'
#  'Biosystems Engineering' 'Reliability Engineering & System Safety'
#  'Computers & Security' 'Cognitive Development'
#  'Environmental Modelling & Software' 'Brain, Behavior, and Immunity'
#  'The Journal of Strategic Information Systems'
#  'Journal of Building Engineering'
#  'International Journal of Innovation Studies' 'Procedia Engineering'
#  'Computers in Human Behavior: Artificial Humans'
#  'Electronic Notes in Theoretical Computer Science'
#  'IFAC Proceedings Volumes']
#
# Unique Conferences:
# ['ACM International Conference Proceeding Series' 'IFAC-PapersOnLine'
#  'MobileHCI 2024 Adjunct Proceedings - Publication of the 26th International Conference on Mobile Human-Computer Interaction'
#  'Proceedings - SUI 2024: ACM Symposium on Spatial User Interaction'
#  'DIS 2024 - Proceedings of the 2024 ACM Designing Interactive Systems Conference'
#  'Conference on Human Factors in Computing Systems - Proceedings'
#  'IEEE International Conference on Automation Science and Engineering'
#  'SIGCSE 2024 - Proceedings of the 55th ACM Technical Symposium on Computer Science Education'
#  '2024 4th IEEE International Conference on Software Engineering and Artificial Intelligence, SEAI 2024'
#  'ACM/IEEE International Conference on Human-Robot Interaction'
#  'MESA 2024 - 20th International Conference on Mechatronic, Embedded Systems and Applications, Proceedings'
#  '10th 2024 International Conference on Control, Decision and Information Technologies, CoDIT 2024'
#  'Computers and Industrial Engineering'
#  '2nd International Conference on Sustainable Computing and Smart Systems, ICSCSS 2024 - Proceedings'
#  'Proceedings of the Conference on Production Systems and Logistics'
#  'Proceedings - IEEE International Conference on Robotics and Automation'
#  'Proceedings of InC4 2024 - 2024 IEEE International Conference on Contemporary Computing and Communications'
#  'Proceedings of the World Congress on Electrical Engineering and Computer Systems and Science'
#  'ICNC-FSKD 2024 - 20th International Conference on Natural Computation, Fuzzy Systems and Knowledge Discovery'
#  'Advances in Transdisciplinary Engineering'
#  '2024 21st International Conference on Ubiquitous Robots, UR 2024'
#  "2024 IEEE International Students' Conference on Electrical, Electronics and Computer Science, SCEECS 2024"
#  'Construction Research Congress 2024, CRC 2024'
#  'Proceedings of the International Symposium on Automation and Robotics in Construction'
#  '2024 International Conference on Emerging Smart Computing and Informatics, ESCI 2024'
#  'Procedia Computer Science'
#  'ICAIF 2023 -  4th ACM International Conference on AI in Finance'
#  '2024 IEEE 2nd International Conference on Control, Electronics and Computer Technology, ICCECT 2024'
#  'Proceedings of the Design Society'
#  '7th International Conference on Inventive Computation Technologies, ICICT 2024'
#  'Computing in Civil Engineering 2023: Resilience, Safety, and Sustainability - Selected Papers from the ASCE International Conference on Computing in Civil Engineering 2023'
#  '2024 IEEE International Conference on Pervasive Computing and Communications Workshops and other Affiliated Events, PerCom Workshops 2024'
#  'Proceedings of the 8th International Symposium on Reliability Engineering and Risk Management, ISRERM 2022'
#  'Procedia CIRP'
#  'Proceedings of SPIE - The International Society for Optical Engineering'
#  'Proceedings - 2nd International Conference on Advancement in Computation and Computer Technologies, InCACCT 2024'
#  '2024 2nd International Conference on Disruptive Technologies, ICDT 2024'
#  'Proceedings - 2024 IEEE Winter Conference on Applications of Computer Vision Workshops, WACVW 2024'
#  'Computing in Civil Engineering 2023: Data, Sensing, and Analytics - Selected Papers from the ASCE International Conference on Computing in Civil Engineering 2023'
#  '2024 International Conference on Cognitive Robotics and Intelligent Systems, ICC - ROBINS 2024'
#  'Proceedings - 2024 International Conference on Electrical Drives, Power Electronics and Engineering, EDPEE 2024'
#  '2024 IEEE/SICE International Symposium on System Integration, SII 2024'
#  'Proceedings of the 2024 IEEE International Conference on Industry 4.0, Artificial Intelligence, and Communications Technology, IAICT 2024'
#  '2024 ASU International Conference in Emerging Technologies for Sustainability and Intelligent Systems, ICETSIS 2024'
#  '2024 International Conference on System Science and Engineering, ICSSE 2024'
#  'Eye Tracking Research and Applications Symposium (ETRA)'
#  'Proceedings of the 5th International Conference on Conversational User Interfaces, CUI 2023'
#  'Proceedings - 2023 8th International Conference on Data Science in Cyberspace, DSC 2023'
#  'IEEE International Workshop on Robot and Human Communication, RO-MAN'
#  '2023 5th International Conference on System Reliability and Safety Engineering, SRSE 2023'
#  'Conference Proceedings - IEEE International Conference on Systems, Man and Cybernetics'
#  '2023 14th International Conference on Computing Communication and Networking Technologies, ICCCNT 2023'
#  '2023 15th IEEE International Conference on Industry Applications, INDUSCON 2023 - Proceedings'
#  '2023 IEEE International Black Sea Conference on Communications and Networking, BlackSeaCom 2023'
#  'Eurasia Proceedings of Science, Technology, Engineering and Mathematics'
#  'Proceedings of the ASME Design Engineering Technical Conference'
#  'Proceedings - International Conference on Network Protocols, ICNP'
#  'ICAC 2023 - 28th International Conference on Automation and Computing'
#  'IEEE International Conference on Intelligent Robots and Systems'
#  'International Conference on ICT Convergence'
#  'IET Conference Proceedings'
#  'CHIIR 2023 - Proceedings of the 2023 Conference on Human Information Interaction and Retrieval'
#  '2023 International Conference on Communication, Security and Artificial Intelligence, ICCSAI 2023'
#  'IISE Annual Conference and Expo 2023'
#  'Proceedings - 2023 11th International Conference on Information Systems and Computing Technology, ISCTech 2023'
#  '2023 4th International Conference on Artificial Intelligence, Robotics and Control, AIRC 2023'
#  '2023 3rd International Conference on Smart Generation Computing, Communication and Networking, SMART GENCON 2023'
#  'Proceedings of 18th International Probabilistic Safety Assessment and Analysis, PSA 2023'
#  '2023 IEEE International Conference on Industrial Engineering and Engineering Management, IEEM 2023'
#  'Proceedings - 2023 IEEE 34th International Symposium on Software Reliability Engineering Workshop, ISSREW 2023'
#  '2023 International Conference on Next Generation Electronics, NEleX 2023'
#  'Proceedings of the 6th International Serious Games Symposium, ISGS 2023'
#  'Advances in Science and Technology'
#  '2023 International Conference on Consumer Electronics - Taiwan, ICCE-Taiwan 2023 - Proceedings'
#  'Proceedings - 4th IEEE 2023 International Conference on Computing, Communication, and Intelligent Systems, ICCCIS 2023'
#  'Proceedings - 2023 3rd International Conference on Robotics, Automation and Intelligent Control, ICRAIC 2023'
#  'IEEE-RAS International Conference on Humanoid Robots'
#  'Proceedings - 2023 International Conference on Mechatronics, IoT and Industrial Informatics, ICMIII 2023'
#  'International Conference on Self Sustainable Artificial Intelligence Systems, ICSSAS 2023 - Proceedings'
#  'Proceedings - 2023 International Conference on Advanced Computing and Communication Technologies, ICACCTech 2023'
#  'International Conference on Intelligent User Interfaces, Proceedings IUI'
#  '2023 1st International Conference on Cognitive Computing and Engineering Education, ICCCEE 2023'
#  'SEFI 2023 - 51st Annual Conference of the European Society for Engineering Education: Engineering Education for Sustainability, Proceedings'
#  'Proceedings of 13th Nuclear Plant Instrumentation, Control and Human-Machine Interface Technologies, NPIC and HMIT 2023'
#  'Proceedings - 2023 IEEE Visualization Conference - Short Papers, VIS 2023'
#  'OCIT 2023 - 21st International Conference on Information Technology, Proceedings'
#  'Proceedings of World Multi-Conference on Systemics, Cybernetics and Informatics, WMSCI'
#  'ASME International Mechanical Engineering Congress and Exposition, Proceedings (IMECE)'
#  '2023 IEEE Gaming, Entertainment, and Media Conference, GEM 2023'
#  '7th IEEE International Conference on Transportation Information and Safety, ICTIS 2023'
#  'IECON Proceedings (Industrial Electronics Conference)'
#  'Proceedings - IEEE 2023 5th International Conference on Advances in Computing, Communication Control and Networking, ICAC3N 2023'
#  '2023 International Conference on IT Innovation and Knowledge Discovery, ITIKD 2023'
#  'International Conference of Young Specialists on Micro/Nanotechnologies and Electron Devices, EDM'
#  '2023 IEEE/SICE International Symposium on System Integration, SII 2023'
#  'Proceedings - 10th International Conference on Electrical, Electronic and Computing Engineering, IcETRAN 2023'
#  '2023 IEEE 3rd International Conference on Computer Communication and Artificial Intelligence, CCAI 2023'
#  '2023 19th International Conference on Intelligent Environments, IE 2023 - Proceedings'
#  'Proceedings - 2023 International Conference on Frontiers of Robotics and Software Engineering, FRSE 2023'
#  'Proceedings of 10th International Conference on Recent Advances in Air and Space Technologies, RAST 2023'
#  '2023 World Conference on Communication and Computing, WCONF 2023'
#  'Proceedings of the International Conference on Offshore Mechanics and Arctic Engineering - OMAE'
#  'Proceedings of IEEE/IFIP Network Operations and Management Symposium 2023, NOMS 2023'
#  'Proceedings - 2023 International Russian Smart Industry Conference, SmartIndustryCon 2023'
#  'Proceedings - 2023 IEEE Conference on Virtual Reality and 3D User Interfaces Abstracts and Workshops, VRW 2023'
#  'Proceedings of the International Florida Artificial Intelligence Research Society Conference, FLAIRS'
#  'Proceedings of the 2023 2nd International Conference on Electronics and Renewable Systems, ICEARS 2023'
#  'Engineering for Rural Development'
#  'Proceedings - Annual Reliability and Maintainability Symposium'
#  'Proceedings of the 7th International Conference on Intelligent Computing and Control Systems, ICICCS 2023'
#  '2023 IEEE Latin American Electron Devices Conference, LAEDC 2023'
#  'Proceedings of the Annual Offshore Technology Conference'
#  '2023 9th International Conference on eDemocracy and eGovernment, ICEDEG 2023'
#  '7th International Conference on Trends in Electronics and Informatics, ICOEI 2023 - Proceedings'
#  '2023 8th IEEE International Conference on Advanced Robotics and Mechatronics, ICARM 2023'
#  '35th British HCI Conference Towards a Human-Centred Digital Society, HCI 2022'
#  'Proceedings of the ACM SIGMOD International Conference on Management of Data'
#  'SAE Technical Papers'
#  'Electronic Proceedings in Theoretical Computer Science, EPTCS'
#  'International Journal of Mechatronics and Manufacturing Systems'
#  'RO-MAN 2022 - 31st IEEE International Conference on Robot and Human Interactive Communication: Social, Asocial, and Antisocial Robots'
#  '2022 28th International Conference on Mechatronics and Machine Vision in Practice, M2VIP 2022'
#  'Proceedings of the 32nd European Safety and Reliability Conference, ESREL 2022 - Understanding and Managing Risk and Reliability for a Sustainable Future'
#  'Proceedings - 2022 3rd International Conference on Education, Knowledge and Information Management, ICEKIM 2022'
#  '2022 IEEE International Workshop on Metrology for Extended Reality, Artificial Intelligence and Neural Engineering, MetroXRAINE 2022 - Proceedings'
#  '2022 10th International Conference on Affective Computing and Intelligent Interaction Workshops and Demos, ACIIW 2022'
#  'International Interdisciplinary Humanitarian Conference for Sustainability, IIHC 2022 - Proceedings'
#  'Proceedings - 2022 IEEE 8th International Conference on Collaboration and Internet Computing, CIC 2022'
#  'AIAA/IEEE Digital Avionics Systems Conference - Proceedings'
#  '2022 13th International Conference on Computing Communication and Networking Technologies, ICCCNT 2022'
#  '2022 IEEE 1st International Conference on Internet of Digital Reality, IoD 2022'
#  '2022 27th International Conference on Automation and Computing: Smart Systems and Manufacturing, ICAC 2022'
#  'IEEE International Conference on Emerging Technologies and Factory Automation, ETFA'
#  'Proceedings - 2022 IEEE/ACIS 7th International Conference on Big Data, Cloud Computing, and Data Science, BCD 2022'
#  'Proceedings of 2022 IEEE 21st International Conference on Cognitive Informatics and Cognitive Computing, ICCI*CC 2022'
#  '3rd IEEE 2022 International Conference on Computing, Communication, and Intelligent Systems, ICCCIS 2022'
#  'Proceedings - 2022 International Conference on Cyberworlds, CW 2022'
#  'IEEE International Conference on Industrial Engineering and Engineering Management'
#  'Proceedings of the 2022 IEEE International Conference on Human-Machine Systems, ICHMS 2022'
#  '2022 3rd International Conference on Intelligent Design, ICID 2022'
#  'Proceedings - Frontiers in Education Conference, FIE'
#  'Proceedings - 2022 IEEE International Symposium on Mixed and Augmented Reality Adjunct, ISMAR-Adjunct 2022'
#  'Lecture Notes in Information Systems and Organisation'
#  '2022 IEEE 1st International Conference on Cognitive Mobility, CogMob 2022'
#  'International Journal of Simulation and Process Modelling'
#  'Proceedings - 2022 IEEE International Symposium on Mixed and Augmented Reality, ISMAR 2022'
#  'ICSSE 2022 - 2022 International Conference on System Science and Engineering'
#  '2022 International Conference on Interactive Media, Smart Systems and Emerging Technologies, IMET 2022 - Proceedings'
#  '2022 IEEE Integrated STEM Education Conference, ISEC 2022'
#  'ICIEA 2022 - Proceedings of the 17th IEEE Conference on Industrial Electronics and Applications'
#  'Construction Research Congress 2022: Computer Applications, Automation, and Data Analytics - Selected Papers from Construction Research Congress 2022'
#  'HORA 2022 - 4th International Congress on Human-Computer Interaction, Optimization and Robotic Applications, Proceedings'
#  '8th International Conference on Smart Structures and Systems, ICSSS 2022'
#  'AIAA AVIATION 2022 Forum'
#  'Construction Research Congress 2022: Health and Safety, Workforce, and Education - Selected Papers from Construction Research Congress 2022'
#  '2022 IEEE 2nd International Conference on Power, Electronics and Computer Applications, ICPECA 2022'
#  'Proceedings - IEEE 19th International Conference on Software Architecture, ICSA 2022'
#  'Applied Ergonomics'
#  'SysCon 2022 - 16th Annual IEEE International Systems Conference, Proceedings'
#  'Proceedings of the IEEE/IFIP Network Operations and Management Symposium 2022: Network and Service Management in the Era of Cloudification, Softwarization and Artificial Intelligence, NOMS 2022'
#  'Proceedings - 2022 IEEE Conference on Virtual Reality and 3D User Interfaces Abstracts and Workshops, VRW 2022'
#  '2022 IEEE International Symposium on Advanced Control of Industrial Processes, AdCONIP 2022'
#  'Proceedings - 2022 IEEE International Conference on Services Computing, SCC 2022'
#  'Proceedings - 16th IEEE International Conference on Semantic Computing, ICSC 2022'
#  'Canadian Conference on Electrical and Computer Engineering'
#  'EICS 2021 - Companion of the 2021 ACM SIGCHI Symposium on Engineering Interactive Computing Systems'
#  'International IEEE/EMBS Conference on Neural Engineering, NER'
#  'Proceedings - 2021 IEEE International Conference on Cognitive and Computational Aspects of Situation Management, CogSIMA 2021'
#  'ICMI 2021 Companion - Companion Publication of the 2021 International Conference on Multimodal Interaction'
#  'Proceedings - 2021 International Symposium on Educational Technology, ISET 2021'
#  'WIT Transactions on the Built Environment'
#  'MM 2021 - Proceedings of the 29th ACM International Conference on Multimedia'
#  '2021 International Conference on Green Energy, Computing and Sustainable Technology, GECOST 2021'
#  'Proceedings of the 2021 IEEE International Conference on Human-Machine Systems, ICHMS 2021'
#  '2021 IEEE International Conference on Technology and Entrepreneurship, ICTE 2021'
#  '2021 7th International Conference on Advanced Computing and Communication Systems, ICACCS 2021'
#  'ICAS 2021 - 2021 IEEE International Conference on Autonomous Systems, Proceedings'
#  '2021 30th IEEE International Conference on Robot and Human Interactive Communication, RO-MAN 2021'
#  '2021 6th IEEE International Conference on Advanced Robotics and Mechatronics, ICARM 2021'
#  '2021 International Conference on Maintenance and Intelligent Asset Management, ICMIAM 2021'
#  'Proceedings - 2021 IEEE International Conference on Services Computing, SCC 2021'
#  'International Joint Conference on Computational Intelligence'
#  'Proceedings - 2021 International Conference on Cyberworlds, CW 2021'
#  '2021 IEEE International Conference on Industrial Engineering and Engineering Management, IEEM 2021'
#  '2021 IEEE International Conference on Consumer Electronics-Taiwan, ICCE-TW 2021'
#  '2021 5th International Conference on System Reliability and Safety, ICSRS 2021'
#  '2021 International Conference on Decision Aid Sciences and Application, DASA 2021'
#  'Procedia Manufacturing'
#  '2021 International Wireless Communications and Mobile Computing, IWCMC 2021'
#  'Proceedings - IEEE International Symposium on Circuits and Systems'
#  'Proceedings of the IEEE Conference on Decision and Control'
#  '2021 26th International Conference on Automation and Computing: System Intelligence through Automation and Computing, ICAC 2021'
#  '2021 20th International Conference on Advanced Robotics, ICAR 2021'
#  'IS and T International Symposium on Electronic Imaging Science and Technology'
#  'Proceedings of Technical Papers - International Microsystems, Packaging, Assembly, and Circuits Technology Conference, IMPACT'
#  'Proceedings of the 31st European Safety and Reliability Conference, ESREL 2021'
#  '2021 International Conference on Advance Computing and Innovative Technologies in Engineering, ICACITE 2021'
#  'Proceedings of International Conference on Electronics, Communications and Information Technology, ICECIT 2021'
#  'Computing in Civil Engineering 2021 - Selected Papers from the ASCE International Conference on Computing in Civil Engineering 2021'
#  'Proceedings - 2021 International Conference on Industrial Engineering, Applications and Manufacturing, ICIEAM 2021'
#  'Proceedings - 24th International Conference on Model-Driven Engineering Languages and Systems, MODELS 2021'
#  'Proceedings of the 11th IEEE International Conference on Intelligent Data Acquisition and Advanced Computing Systems: Technology and Applications, IDAACS 2021'
#  'Proceedings of International Conference on Innovative Practices in Technology and Management, ICIPTM 2021'
#  '6th International Forum on Research and Technology for Society and Industry, RTSI 2021 - Proceedings'
#  '2nd International Informatics and Software Engineering Conference, IISEC 2021'
#  'Proceedings of the 18th International Conference on Informatics in Control, Automation and Robotics, ICINCO 2021'
#  'Proceedings of the European Conference on Games-based Learning'
#  '2021 International Conference on Computational Intelligence and Computing Applications, ICCICA 2021'
#  'Proceedings of the 4th International Conference on IoT in Social, Mobile, Analytics and Cloud, ISMAC 2020'
#  '2020 IFEES World Engineering Education Forum - Global Engineering Deans Council, WEEF-GEDC 2020'
#  'Proceedings - 2020 22nd Symposium on Virtual and Augmented Reality, SVR 2020'
#  'Proceedings of the Annual Conference of the Prognostics and Health Management Society, PHM'
#  'Proceedings - 2020 IEEE International Symposium on Mixed and Augmented Reality, ISMAR 2020'
#  '2020 4th CAA International Conference on Vehicular Control and Intelligence, CVCI 2020'
#  'Proceedings - 2020 International Conference on Computational Science and Computational Intelligence, CSCI 2020'
#  'IEEE International Conference on Industrial Informatics (INDIN)'
#  'Proceedings of the ACM Symposium on Virtual Reality Software and Technology, VRST'
#  'Proceedings - 2020 IEEE International Conference on Software Maintenance and Evolution, ICSME 2020'
#  'Adjunct Proceedings of the 2020 IEEE International Symposium on Mixed and Augmented Reality, ISMAR-Adjunct 2020'
#  '29th IEEE International Conference on Robot and Human Interactive Communication, RO-MAN 2020'
#  'Proceedings - 2020 International Conference on Computing and Data Science, CDS 2020'
#  'International Conference on Advanced Communication Technologies and Signal Processing, ACTS 2020'
#  'Proceedings - 2021 IEEE 15th International Conference on Semantic Computing, ICSC 2021'
#  'UbiComp/ISWC 2020 Adjunct - Proceedings of the 2020 ACM International Joint Conference on Pervasive and Ubiquitous Computing and Proceedings of the 2020 ACM International Symposium on Wearable Computers'
#  'Proceedings of the 2020 IEEE International Conference on Human-Machine Systems, ICHMS 2020'
#  '2020 2nd International Conference on Sustainable Technologies for Industry 4.0, STI 2020'
#  'Proceedings - 2020 IEEE 2nd International Conference on Cognitive Machine Intelligence, CogMI 2020'
#  '11th IEEE International Conference on Cognitive Infocommunications, CogInfoCom 2020 - Proceedings'
#  'IOP Conference Series: Materials Science and Engineering'
#  'Proceedings - 2020 3rd International Conference on Artificial Intelligence for Industries, AI4I 2020'
#  '2020 IEEE 10th International Conference on Intelligent Systems, IS 2020 - Proceedings'
#  'Proceedings of 2020 IEEE International Conference on Progress in Informatics and Computing, PIC 2020'
#  'Proceedings of the Design Society: DESIGN Conference'
#  '2020 International Conference on System, Computation, Automation and Networking, ICSCAN 2020'
#  'International Conference on Advanced Communication Technology, ICACT'
#  'Proceedings of 2020 IEEE 4th Information Technology, Networking, Electronic and Automation Control Conference, ITNEC 2020'
#  'IEEE IAS Electrical Safety Workshop'
#  'IEEE International Symposium on Industrial Electronics'
#  'Proceedings of the NordDesign 2020 Conference, NordDesign 2020'
#  'Proceedings - 2020 IEEE Conference on Virtual Reality and 3D User Interfaces, VRW 2020'
#  'ASME 2020 15th International Manufacturing Science and Engineering Conference, MSEC 2020'
#  'Proceedings of the International Conference on Intelligent Computing and Control Systems, ICICCS 2020'
#  'Proceedings of the Annual International Conference of the IEEE Engineering in Medicine and Biology Society, EMBS'
#  'Proceedings of IEEE Computer Society Annual Symposium on VLSI, ISVLSI'
#  'IN4PL - Proceedings of the International Conference on Innovative Intelligent Industrial Production and Logistics'
#  '2020 International Conference on Industry 4.0 Technology, I4Tech 2020'
#  'International Conference on Emerging Trends in Information Technology and Engineering, ic-ETITE 2020'
#  '2020 IEEE International Workshop on Metrology for AeroSpace, MetroAeroSpace 2020 - Proceedings'
#  '2020 Pan Pacific Microelectronics Symposium, Pan Pacific 2020'
#  '2020 9th Mediterranean Conference on Embedded Computing, MECO 2020'
#  'IEEE International Conference on Fuzzy Systems'
#  '2020 IEEE Technology and Engineering Management Conference, TEMSCON 2020'
#  'Proceeding - ICoSTA 2020: 2020 International Conference on Smart Technology and Applications: Empowering Industrial IoT by Implementing Green Technology for Sustainable Development'
#  '2020 IEEE International Workshop on Metrology for Industry 4.0 and IoT, MetroInd 4.0 and IoT 2020 - Proceedings'
#  'IEEE Aerospace Conference Proceedings'
#  'IEEE/ASME International Conference on Advanced Intelligent Mechatronics, AIM'
#  'I2MTC 2020 - International Instrumentation and Measurement Technology Conference, Proceedings'
#  '10th IEEE International Conference on Cognitive Infocommunications, CogInfoCom 2019 - Proceedings'
#  'IEEE Region 10 Annual International Conference, Proceedings/TENCON'
#  'Proceedings of the 29th European Safety and Reliability Conference, ESREL 2019'
#  'Construction Research Congress 2020: Infrastructure Systems and Sustainability - Selected Papers from the Construction Research Congress 2020'
#  'Construction Research Congress 2020: Safety, Workforce, and Education - Selected Papers from the Construction Research Congress 2020'
#  'AIAA AVIATION 2020 FORUM'
#  'Proceedings - 2019 Brazilian Conference on Intelligent Systems, BRACIS 2019'
#  '2020 International Conference on Computer Communication and Informatics, ICCCI 2020'
#  '2020 3rd International Conference on Computing, Mathematics and Engineering Technologies: Idea to Innovation for Building the Knowledge Economy, iCoMET 2020'
#  '2019 28th IEEE International Conference on Robot and Human Interactive Communication, RO-MAN 2019'
#  'Proceedings of the International Conference on Intellectual Capital, Knowledge Management and Organisational Learning, ICICKM'
#  'International Journal of Mobile Learning and Organisation'
#  'Digest of Technical Papers - SID International Symposium'
#  'International Conference of Control, Dynamic Systems, and Robotics'
# ...
#  'SIGGRAPH 2016 - ACM SIGGRAPH 2016 Talks'
#  'Proceedings of the Annual Hawaii International Conference on System Sciences'
#  'ASSETS 2016 - Proceedings of the 18th International ACM SIGACCESS Conference on Computers and Accessibility'
#  'Wireless Telecommunications Symposium'
#  'Proceedings - IEEE Symposium on Computer-Based Medical Systems'
#  'Proceedings of the NOMS 2016 - 2016 IEEE/IFIP Network Operations and Management Symposium'
#  'Proceedings of the Biennial International Pipeline Conference, IPC'
#  'International Symposium on Technology and Society, Proceedings'
#  'Proceedings of 2015 International Conference on Industrial Engineering and Systems Management, IEEE IESM 2015'
#  'HAI 2015 - Proceedings of the 3rd International Conference on Human-Agent Interaction'
#  '2015 Systems and Information Engineering Design Symposium, SIEDS 2015'
#  '15th AIAA Aviation Technology, Integration, and Operations Conference'
#  'UbiComp and ISWC 2015 - Proceedings of the 2015 ACM International Joint Conference on Pervasive and Ubiquitous Computing and the Proceedings of the 2015 ACM International Symposium on Wearable Computers'
#  '2015 European Conference on Networks and Communications, EuCNC 2015'
#  'European Journal of Industrial Engineering'
#  '2015 4th International Conference on Informatics, Electronics and Vision, ICIEV 2015'
#  'Proceedings of the 2015 ACM International Conference on Interactive Tabletops and Surfaces, ITS 2015'
#  'Proceedings of 2015 IEEE International Conference on Electrical, Computer and Communication Technologies, ICECCT 2015'
#  'Proceedings of 2015 the 1st International Conference on Reliability Systems Engineering, ICRSE 2015'
#  'Proceedings of the 2015 10th IEEE Conference on Industrial Electronics and Applications, ICIEA 2015'
#  'Proceedings of the International Symposium on Wireless Communication Systems'
#  'International Journal of Manufacturing Technology and Management'
#  '2015 3rd IEEE VR International Workshop on Virtual and Augmented Assistive Technology, VAAT 2015'
#  '2015 IEEE 23rd International Requirements Engineering Conference, RE 2015 - Proceedings'
#  'BIOSIGNALS 2016 - 9th International Conference on Bio-Inspired Systems and Signal Processing, Proceedings; Part of 9th International Joint Conference on Biomedical Engineering Systems and Technologies, BIOSTEC 2016'
#  'ICAART 2016 - Proceedings of the 8th International Conference on Agents and Artificial Intelligence'
#  '2015 IEEE International Conference on Mechatronics and Automation, ICMA 2015'
#  'ISARC 2016 - 33rd International Symposium on Automation and Robotics in Construction'
#  '2015 IEEE International Symposium on Dynamic Spectrum Access Networks, DySPAN 2015'
#  'PhyCS 2016 - Proceedings of the 3rd International Conference on Physiological Computing Systems'
#  'Proceedings of 2014 International Conference on Localization and GNSS, ICL-GNSS 2014'
#  'SKIMA 2014 - 8th International Conference on Software, Knowledge, Information Management and Applications'
#  'IET Conference Publications'
#  '5th IEEE International Conference on Cognitive Infocommunications, CogInfoCom 2014 - Proceedings'
#  'Proceedings of the NordiCHI 2014: The 8th Nordic Conference on Human-Computer Interaction: Fun, Fast, Foundational'
#  'IEEE RO-MAN 2014 - 23rd IEEE International Symposium on Robot and Human Interactive Communication: Human-Robot Co-Existence: Adaptive Interfaces and Systems for Daily Life, Therapy, Assistance and Socially Engaging Interactions'
#  '2014 6th World Congress on Nature and Biologically Inspired Computing, NaBIC 2014'
#  '2014 36th Annual International Conference of the IEEE Engineering in Medicine and Biology Society, EMBC 2014'
#  'Safety and Reliability of Complex Engineered Systems - Proceedings of the 25th European Safety and Reliability Conference, ESREL 2015'
#  'ICRMS 2014 - Proceedings of 2014 10th International Conference on Reliability, Maintainability and Safety: More Reliable Products, More Secure Life'
#  'EMASC 2014 - Proceedings of the 1st International Workshop on Emerging Multimedia Applications and Services for Smart Cities, Workshop of MM 2014'
#  'INES 2014 - IEEE 18th International Conference on Intelligent Engineering Systems, Proceedings'
#  'ICAART 2015 - 7th International Conference on Agents and Artificial Intelligence, Proceedings'
#  '2009 European Control Conference, ECC 2009'
#  '2014 17th IEEE International Conference on Intelligent Transportation Systems, ITSC 2014'
#  '2014 IEEE International Conference on Robotics and Biomimetics, IEEE ROBIO 2014'
#  'Safety and Reliability: Methodology and Applications - Proceedings of the European Safety and Reliability Conference, ESREL 2014'
#  'Proceedings of the International Conference on Software Engineering and Knowledge Engineering, SEKE'
#  'IECON 2015 - 41st Annual Conference of the IEEE Industrial Electronics Society'
#  'SPE/IADC Drilling Conference, Proceedings'
#  'CINTI 2014 - 15th IEEE International Symposium on Computational Intelligence and Informatics, Proceedings'
#  '1st International Conference on Networks and Soft Computing, ICNSC 2014 - Proceedings'
#  'Mechanisms and Machine Science' 'Gerontechnology'
#  'Computing in Civil and Building Engineering - Proceedings of the 2014 International Conference on Computing in Civil and Building Engineering'
#  'IFAC Proceedings Volumes (IFAC-PapersOnline)'
#  'CONIELECOMP 2014 - 24th International Conference on Electronics, Communications and Computers'
#  'SeGAH 2014 - IEEE 3rd International Conference on Serious Games and Applications for Health, Books of Proceedings'
#  'COLLABORATIVE NETWORKS OF COGNITIVE SYSTEMS'
#  '2020 IEEE INTERNATIONAL CONFERENCE ON INDUSTRIAL ENGINEERING AND ENGINEERING MANAGEMENT (IEEE IEEM)'
#  'BOOSTING COLLABORATIVE NETWORKS 4.0: 21ST IFIP WG 5.5 WORKING CONFERENCE ON VIRTUAL ENTERPRISES, PRO-VE 2020'
#  '30TH INTERNATIONAL CONFERENCE ON FLEXIBLE AUTOMATION AND INTELLIGENT MANUFACTURING (FAIM2021)'
#  'ADVANCES IN NEUROERGONOMICS AND COGNITIVE ENGINEERING'
#  '29TH EUROPEAN SYMPOSIUM ON COMPUTER AIDED PROCESS ENGINEERING, PT B'
#  'DIGITAL HUMAN MODELING AND APPLICATIONS IN HEALTH, SAFETY, ERGONOMICS AND RISK MANAGEMENT, PT I, DHM 2024'
#  'HUMAN-COMPUTER INTERACTION - INTERACT 2023, PT II'
#  'VIRTUAL, AUGMENTED AND MIXED REALITY: APPLICATIONS AND CASE STUDIES, VAMR 2019, PT II'
#  'ADVANCES IN PRODUCTION MANAGEMENT SYSTEMS: SMART MANUFACTURING AND LOGISTICS SYSTEMS: TURNING IDEAS INTO ACTION, APMS 2022, PT II'
#  '2019 IEEE INTERNATIONAL CONFERENCE ON INDUSTRIAL ENGINEERING AND ENGINEERING MANAGEMENT (IEEM)'
#  'COMPUTER SAFETY, RELIABILITY, AND SECURITY, SAFECOMP 2017'
#  'NEW TECHNOLOGIES, DEVELOPMENT AND APPLICATION VI, VOL 1'
#  'BUSINESS PROCESS MANAGEMENT WORKSHOPS, BPM 2018 INTERNATIONAL WORKSHOPS'
#  'ADVANCES IN ARTIFICIAL INTELLIGENCE IN MANUFACTURING, ESAIM 2023'
#  '8TH INTERNATIONAL WORKSHOP ON SERVICE ORIENTATION IN HOLONIC AND MULTI-AGENT MANUFACTURING, SOHOMA 2018'
#  'INDUSTRIAL ENGINEERING IN THE INTERNET-OF-THINGS WORLD, GJCIE 2020'
#  'ADVANCES IN PRODUCTION MANAGEMENT SYSTEMS: ARTIFICIAL INTELLIGENCE FOR SUSTAINABLE AND RESILIENT PRODUCTION SYSTEMS, PT V'
#  'CONFERENCE PROCEEDINGS OF 2019 5TH INTERNATIONAL CONFERENCE ON CONTROL, AUTOMATION AND ROBOTICS (ICCAR)'
#  '2019 IEEE 15TH INTERNATIONAL CONFERENCE ON AUTOMATION SCIENCE AND ENGINEERING (CASE)'
#  'INDUSTRIAL ENGINEERING AND OPERATIONS MANAGEMENT, XXVIII IJCIEOM'
#  'AGENTS AND ARTIFICIAL INTELLIGENCE, ICAART 2015'
#  'RECENT ADVANCES IN SYSTEMS, CONTROL AND INFORMATION TECHNOLOGY'
#  'HCI IN BUSINESS, GOVERNMENT AND ORGANIZATIONS: INTERACTING WITH INFORMATION SYSTEMS, PT I'
#  'HCI IN MOBILITY, TRANSPORT, AND AUTOMOTIVE SYSTEMS, MOBITAS 2024, PT I'
#  'ADVANCES IN HUMAN FACTORS IN ENERGY: OIL, GAS, NUCLEAR AND ELECTRIC POWER INDUSTRIES'
#  'ADVANCES IN PRODUCTION MANAGEMENT SYSTEMS: TOWARDS SMART AND DIGITAL MANUFACTURING, PT II'
#  'ADVANCED SOLUTIONS IN DIAGNOSTICS AND FAULT TOLERANT CONTROL'
#  'REQUIREMENTS ENGINEERING: FOUNDATION FOR SOFTWARE QUALITY, REFSQ 2017'
#  'ADVANCES IN MANUFACTURING, PRODUCTION MANAGEMENT AND PROCESS CONTROL'
#  'ENGINEERING PSYCHOLOGY AND COGNITIVE ERGONOMICS. COGNITION AND DESIGN, EPCE 2020, PT II'
#  "ICMI'15: PROCEEDINGS OF THE 2015 ACM INTERNATIONAL CONFERENCE ON MULTIMODAL INTERACTION"
#  'AUGMENTED COGNITION: NEUROCOGNITION AND MACHINE LEARNING, AC 2017, PT I'
#  'ADVANCES ON MECHANICS, DESIGN ENGINEERING AND MANUFACTURING'
#  'ADVANCES IN SOCIAL & OCCUPATIONAL ERGONOMICS, AHFE 2017'
#  'SYSTEMS, SOFTWARE AND SERVICES PROCESS IMPROVEMENT, EUROSPI 2021'
#  'COMPUTATIONAL SCIENCE AND ITS APPLICATIONS - ICCSA 2020, PT II'
#  'CYBER-PHYSICAL SYSTEMS AND CONTROL'
#  'HCI FOR CYBERSECURITY, PRIVACY AND TRUST, HCI-CPT 2020'
#  'PROCEEDINGS OF 2020 IEEE 19TH INTERNATIONAL CONFERENCE ON COGNITIVE INFORMATICS & COGNITIVE COMPUTING (ICCI*CC 2020)'
#  'VIRTUAL, AUGMENTED AND MIXED REALITY'
#  'Engineering Psychology and Cognitive Ergonomics, (EPCE 2016)'
#  'HAPTICS: SCIENCE, TECHNOLOGY, AND APPLICATIONS, PT II'
#  'ENGINEERING PSYCHOLOGY AND COGNITIVE ERGONOMICS, PT II, EPCE 2024'
#  '2019 IEEE 17TH INTERNATIONAL CONFERENCE ON INDUSTRIAL INFORMATICS (INDIN)'
#  'DESIGN TOOLS AND METHODS IN INDUSTRIAL ENGINEERING II, ADM 2021'
#  'ADVANCES IN SOCIAL & OCCUPATIONAL ERGONOMICS'
#  'ADVANCES IN HUMAN ERROR, RELIABILITY, RESILIENCE, AND PERFORMANCE'
#  '26TH EUROPEAN SYMPOSIUM ON COMPUTER AIDED PROCESS ENGINEERING (ESCAPE), PT B'
#  'HUMAN-COMPUTER INTERACTION: THEORY, METHODS AND TOOLS, HCII 2021, PT I'
#  'HUMAN SYSTEMS ENGINEERING AND DESIGN, IHSED2018'
#  'FROM BIOINSPIRED SYSTEMS AND BIOMEDICAL APPLICATIONS TO MACHINE LEARNING, PT II'
#  'BIOMIMETIC AND BIOHYBRID SYSTEMS, LIVING MACHINES 2020'
#  'SOCIAL ROBOTICS, ICSR 2021' '2019 IEEE SOUTHEASTCON'
#  'DESIGN, USER EXPERIENCE, AND USABILITY: USERS, CONTEXTS AND CASE STUDIES, DUXU 2018, PT III'
#  'ADVANCES IN AFFECTIVE AND PLEASURABLE DESIGN (AHFE 2017)'
#  'INTELLIGENT HUMAN SYSTEMS INTEGRATION 2021'
#  'HUMAN SYSTEMS ENGINEERING AND DESIGN II'
#  '2022 IEEE/RSJ INTERNATIONAL CONFERENCE ON INTELLIGENT ROBOTS AND SYSTEMS (IROS)'
#  'ADVANCES IN HUMAN FACTORS IN ROBOTS AND UNMANNED SYSTEMS'
#  'PROCEEDINGS OF THE 3RD INTERNATIONAL CONFERENCE ON FINANCE, ECONOMICS, MANAGEMENT AND IT BUSINESS (FEMIB)'
#  'PROCEEDINGS OF THE 20TH CONGRESS OF THE INTERNATIONAL ERGONOMICS ASSOCIATION (IEA 2018), VOL VII: ERGONOMICS IN DESIGN, DESIGN FOR ALL, ACTIVITY THEORIES FOR WORK ANALYSIS AND DESIGN, AFFECTIVE DESIGN'
#  'PROCEEDINGS OF THE 2020 IEEE INTERNATIONAL CONFERENCE ON HUMAN-MACHINE SYSTEMS (ICHMS)'
#  'PROGRESS IN ARTIFICIAL INTELLIGENCE, EPIA 2023, PT II'
#  'SYMBIOTIC INTERACTION (SYMBIOTIC 2016)'
#  'SPATIAL COGNITION XIII, SPATIAL COGNITION 2024'
#  'ADVANCES IN USABILITY, USER EXPERIENCE AND ASSISTIVE TECHNOLOGY'
#  'NATURAL LANGUAGE PROCESSING AND INFORMATION SYSTEMS, NLDB 2015'
#  '2019 14TH ANNUAL CONFERENCE SYSTEM OF SYSTEMS ENGINEERING (SOSE)'
#  '2019 10TH IEEE INTERNATIONAL CONFERENCE ON COGNITIVE INFOCOMMUNICATIONS (COGINFOCOM 2019)'
#  'HCI IN MOBILITY, TRANSPORT, AND AUTOMOTIVE SYSTEMS, MOBITAS 2021'
#  'EXPLORING SERVICE SCIENCE (IESS 2020)'
#  'JOURNAL OF WORK AND ORGANIZATIONAL PSYCHOLOGY-REVISTA DE PSICOLOGIA DEL TRABAJO Y DE LAS ORGANIZACIONES'
#  'HCI INTERNATIONAL 2021 - LATE BREAKING PAPERS: MULTIMODALITY, EXTENDED REALITY, AND ARTIFICIAL INTELLIGENCE'
#  '2019 IEEE 20TH INTERNATIONAL CONFERENCE ON COMPUTATIONAL PROBLEMS OF ELECTRICAL ENGINEERING (CPEE)'
#  '2023 IEEE-RAS 22ND INTERNATIONAL CONFERENCE ON HUMANOID ROBOTS, HUMANOIDS'
#  'SMART TECHNOLOGY'
#  'COMPUTATIONAL SCIENCE AND ITS APPLICATIONS - ICCSA 2017, PT V'
#  'PROCEEDINGS OF THE 5TH INTERNATIONAL CONFERENCE ON COMPUTER-HUMAN INTERACTION RESEARCH AND APPLICATIONS (CHIRA)'
#  'PROCEEDINGS OF SAI INTELLIGENT SYSTEMS CONFERENCE (INTELLISYS) 2016, VOL 1'
#  '2015 IEEE INTERNATIONAL CONFERENCE ON SYSTEMS, MAN, AND CYBERNETICS (SMC 2015): BIG DATA ANALYTICS FOR HUMAN-CENTRIC SYSTEMS'
#  'ENGINEERING PSYCHOLOGY AND COGNITIVE ERGONOMICS, EPCE 2019'
#  'HCI INTERNATIONAL 2019 - LATE BREAKING POSTERS, HCII 2019'
#  '2020 11TH IEEE INTERNATIONAL CONFERENCE ON COGNITIVE INFOCOMMUNICATIONS (COGINFOCOM 2020)'
#  'ADVANCES IN ERGONOMICS IN DESIGN'
#  'MACHINE LEARNING AND KNOWLEDGE EXTRACTION, CD-MAKE 2018'
#  '2019 12TH INTERNATIONAL CONFERENCE ON HUMAN SYSTEM INTERACTION (HSI)'
#  'PROCEEDINGS OF THE 4TH INTERNATIONAL CONFERENCE ON COMPUTER-HUMAN INTERACTION RESEARCH AND APPLICATIONS (CHIRA)'
#  'ENGINEERING PSYCHOLOGY AND COGNITIVE ERGONOMICS (EPCE 2018)'
#  'INTELLIGENT INFORMATION AND DATABASE SYSTEMS (ACIIDS 2020), PT I'
#  'BUSINESS PROCESS MANAGEMENT WORKSHOPS (BPM 2017)'
#  '2019 28TH IEEE INTERNATIONAL CONFERENCE ON ROBOT AND HUMAN INTERACTIVE COMMUNICATION (RO-MAN)'
#  'INTERACTIVE COLLABORATIVE ROBOTICS (ICR 2019)'
#  'COMPUTER SAFETY, RELIABILITY, AND SECURITY (SAFECOMP 2021)'
#  'ARTSIT, INTERACTIVITY AND GAME CREATION, PT 2, ARTSIT 2023'
#  'HCI IN MOBILITY, TRANSPORT, AND AUTOMOTIVE SYSTEMS. AUTOMATED DRIVING AND IN-VEHICLE EXPERIENCE DESIGN, MOBITAS 2020, PT I'
#  'INTELLIGENT TUTORING SYSTEMS, ITS 2018'
#  'INDUSTRY COMPETITIVENESS: DIGITALIZATION, MANAGEMENT, AND INTEGRATION, VOL 1'
#  'ARTIFICIAL INTELLIGENCE APPLICATIONS AND INNOVATIONS. AIAI 2020 IFIP WG 12.5 INTERNATIONAL WORKSHOPS'
#  'HUMAN ASPECTS OF IT FOR THE AGED POPULATION: DESIGN FOR EVERYDAY LIFE, ITAP 2015, PT II'
#  'DIGITAL TRANSFORMATION AND GLOBAL SOCIETY (DTGS 2017)'
#  'TRENDS AND INNOVATIONS IN INFORMATION SYSTEMS AND TECHNOLOGIES, VOL 1'
#  'PROCEEDINGS OF THE 2024 CHI CONFERENCE ON HUMAN FACTORS IN COMPUTING SYTEMS (CHI 2024)'
#  'ROLE OF DIGITAL TECHNOLOGIES IN SHAPING THE POST-PANDEMIC WORLD'
#  'LEARNING IN THE AGE OF DIGITAL AND GREEN TRANSITION, ICL2022, VOL 1'
#  'ADVANCES IN ERGONOMICS IN DESIGN (AHFE 2017)'
#  "MCPMD'18: PROCEEDINGS OF THE WORKSHOP ON MODELING COGNITIVE PROCESSES FROM MULTIMODAL DATA"
#  '2019 IEEE FRONTIERS IN EDUCATION CONFERENCE (FIE 2019)'
#  'DSS 2.0 - SUPPORTING DECISION MAKING WITH NEW TECHNOLOGIES'
#  '2020 IEEE IAS ELECTRICAL SAFETY WORKSHOP (ESW)'
#  'PRODUCT LIFECYCLE MANAGEMENT: GREEN AND BLUE TECHNOLOGIES TO SUPPORT SMART AND SUSTAINABLE ORGANIZATIONS, PT II'
#  'ARTIFICIAL INTELLIGENCE IN HCI, AI-HCI 2023, PT I'
#  'INTELLIGENT HUMAN SYSTEMS INTEGRATION 2020'
#  'UNIVERSAL ACCESS IN HUMAN-COMPUTER INTERACTION; INTERACTION TECHNIQUES AND ENVIRONMENTS, PT II'
#  '2020 INFORMATION THEORY AND APPLICATIONS WORKSHOP (ITA)'
#  'HUMAN-COMPUTER INTERACTION: INTERACTION TECHNIQUES AND NOVEL APPLICATIONS, HCII 2021, PT II'
#  '2023 PROCEEDINGS OF THE 31ST ACM CONFERENCE ON USER MODELING, ADAPTATION AND PERSONALIZATION, UMAP 2023'
#  '2020 IEEE 7TH INTERNATIONAL WORKSHOP ON METROLOGY FOR AEROSPACE (METROAEROSPACE)'
#  '2020 IEEE 29TH INTERNATIONAL SYMPOSIUM ON INDUSTRIAL ELECTRONICS (ISIE)'
#  'ADVANCES IN AFFECTIVE AND PLEASURABLE DESIGN'
#  'CISAP6: 6TH INTERNATIONAL CONFERENCE ON SAFETY & ENVIRONMENT IN PROCESS & POWER INDUSTRY'
#  'PROCEEDINGS OF 2020 IEEE 4TH INFORMATION TECHNOLOGY, NETWORKING, ELECTRONIC AND AUTOMATION CONTROL CONFERENCE (ITNEC 2020)'
#  'PRODUCT LIFECYCLE MANAGEMENT PLM IN TRANSITION TIMES: THE PLACE OF HUMANS AND TRANSFORMATIVE TECHNOLOGIES, PLM 2022'
#  '2020 IEEE CONFERENCE ON VIRTUAL REALITY AND 3D USER INTERFACES WORKSHOPS (VRW 2020)'
#  'PROCEEDINGS OF THE EUROPEAN CONFERENCE ON THE IMPACT OF ARTIFICIAL INTELLIGENCE AND ROBOTICS (ECIAIR 2019)'
#  'RELIABILITY, SAFETY AND HAZARD ASSESSMENT FOR RISK-BASED TECHNOLOGIES'
#  'RESEARCH AND PRACTICAL ISSUES OF ENTERPRISE INFORMATION SYSTEMS, 10TH IFIP WG 8.9 WORKING CONFERENCE, CONFENIS 2016'
#  'INTERNET OF THINGS, INFRASTRUCTURES AND MOBILE APPLICATIONS'
#  'BUSINESS PROCESS MANAGEMENT: BLOCKCHAIN AND ROBOTIC PROCESS AUTOMATION FORUM, BPM 2021 BLOCKCHAIN AND RPA FORUM'
#  'PROCEEDINGS OF THE INTERNATIONAL CONFERENCE ON INTELLIGENT COMPUTING AND CONTROL SYSTEMS (ICICCS 2020)'
#  'ADVANCES IN ARTIFICIAL INTELLIGENCE, SOFTWARE AND SYSTEMS ENGINEERING'
#  'FRONTIERS OF MANUFACTURING AND DESIGN SCIENCE IV, PTS 1-5'
#  'ARTIFICIAL INTELLIGENCE IN HCI, PT III, AI-HCI 2024'
#  'LEARNING AND COLLABORATION TECHNOLOGIES, LCT 2023, PT I'
#  '12TH NORDIC CONFERENCE ON CONSTRUCTION ECONOMICS AND ORGANISATION, 2024']

# %%
from collections import Counter

# Filter out rows with null values in Keywords
keywords_data = deduped_data[deduped_data["Keywords"].notnull()]["Keywords"]

# Split keywords by semicolon and flatten the list
all_keywords = [keyword.strip().lower() for keywords in keywords_data for keyword in keywords.split(";")]

# Count the frequency of each keyword
keyword_counts = Counter(all_keywords)

# Convert the counts to a DataFrame
keywords_df = pd.DataFrame(keyword_counts.items(), columns=["Keyword", "Count"])

# Sort the DataFrame by frequency in descending order
keywords_df = keywords_df.sort_values(by="Count", ascending=False).reset_index(drop=True)

# Display the top 10 most frequent keywords
keywords_df
# Out:
#                                                 Keyword  Count
# 0                                          industry 4.0    117
# 1                               artificial intelligence     87
# 2                                         human factors     82
# 3                                     augmented reality     79
# 4                                      machine learning     65
# ...                                                 ...    ...
# 6833                                informal leadership      1
# 6834                                  frontline workers      1
# 6835                                 telerehabilitation      1
# 6836                                             stroke      1
# 6837  ['facial expression recognition', 'deep learni...      1
#
# [6838 rows x 2 columns]

# %%
keywords_df.to_csv("./Keywords sorted by frequency.csv")

# %%
# Out:
# Source
# Procedia CIRP                                                                                                108
# IFAC-PapersOnLine                                                                                             65
# ACM International Conference Proceeding Series                                                                55
# Procedia Computer Science                                                                                     55
# Procedia Manufacturing                                                                                        50
#                                                                                                             ...
# Journal of Southeast University (English Edition)                                                              1
# Proceedings of International Conference on Innovative Practices in Technology and Management, ICIPTM 2021      1
# 6th International Forum on Research and Technology for Society and Industry, RTSI 2021 - Proceedings           1
# 2nd International Informatics and Software Engineering Conference, IISEC 2021                                  1
# IFAC Proceedings Volumes                                                                                       1
# Name: count, Length: 1168, dtype: int64
